# %% [markdown]
# We will start List concept and understanding in python.

# %%
first_list = [1,2,3,4]
print(first_list)
# Out:
# [1, 2, 3, 4]

# %%
list = [1,2,3,4,5]
for i in list:
    print(i, end=" ")
# Out:
# 1 2 3 4 5

# %%
list = [1,2,3,4,5]
for i in list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list = [1,2,3,4,5]
print(list[2])
print(list[-1])
# Out:
# 3
# 5

# %% [markdown]
# Slicing

# %%
list = [1,2,3,4,5,6,7,8,9]
print(list[1:3])
print(list[1::])
print(list[::2])
# Out:
# [2, 3]
# [2, 3, 4, 5, 6, 7, 8, 9]
# [1, 3, 5, 7, 9]
