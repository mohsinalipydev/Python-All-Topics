# %% [markdown]
# We will start List concept and understanding in python.

# %%
first_list = [1,2,3,4]
print(first_list)
# Out:
# [1, 2, 3, 4]

# %%
list = [1,2,3,4,5]
for i in list:
    print(i, end=" ")
# Out:
# 1 2 3 4 5

# %%
list = [1,2,3,4,5]
for i in list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list = [1,2,3,4,5]
print(list[2])
print(list[-1])
# Out:
# 3
# 5
