# %% [markdown]
# Task: Create a function that takes two numbers and returns their sum.

# %%
def num(a,b):
    return a+b


num(5,10)
# Out:
# 15

# %% [markdown]
# Task2: Check wheater the number is even of odd

# %%
def check_number(a):
    if a%2==0:
        return "Even"
    else:
        return "Odd"
    
check_number(4)
# Out:
# 'Even'

# %%
def check_number():
    if a%2==0:
        return "Even"
    else:
        return "Odd"
    
a = int(input("Enter a number"))
check_number()
# Out:
# 'Odd'

# %% [markdown]
# Task3: find the biggest number between two numbers

# %%
def find_number(a,b):
    if a>b:
        return "A is Greater"
    else:
        return "B is greater"
    
find_number(2,1)
# Out:
# 'A is Greater'

# %%
def find_number():
    if a>b:
        return "A is greater"
    else:
        return "B is greater"

a = int(input("Enter a number"))
b = int(input("Enter second number"))
find_number()
# Out:
# 'B is greater'

# %% [markdown]
# Task4 : Return the square of a number

# %%
def number(a):
    square = a*a
    return square

number(6)
# Out:
# 36

# %%
def number():
    square = a*a
    return square

a = int(input("Enter a number"))
number()
# Out:
# 25

# %% [markdown]
# Task5: Count the total element in a list

# %%
def count_items(my_list):
    return len(my_list)



number = [1,2,3,4,5,6]
print(count_items(number))
# Out:
# 6

# %% [markdown]
# Task6: Check positive number

# %%
def check_number(a):
    if a>=0:
        return "Positive"
    else:
        return "Negative"

check_number(1)
# Out:
# 'Positive'

# %%
def check_number():
    if a>=0:
        return "Positive"
    else:
        return "Negative"
    
a = int(input("Enter a number"))

check_number()
# Out:
# 'Negative'

# %% [markdown]
# Task7: Calculate Factorial
