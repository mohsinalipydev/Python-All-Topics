# %%
stack = []

stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)

print(stack)


stack.pop()

print(stack)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]

# %%
stack = []

stack.append(1+2)
stack.append(1+3)
stack.append(1+4)
stack.append(1+5)

print(stack)


remove = stack.pop()
print(remove)
print(stack)
# Out:
# [3, 4, 5, 6]
# 6
# [3, 4, 5]

# %% [markdown]
# i we want to find top element in stack

# %%
stack = []


stack.append(1)
stack.append(2)
stack.append(3)

top_element = stack[-1]
print(top_element)
# Out:
# 3

# %%
History = ;
